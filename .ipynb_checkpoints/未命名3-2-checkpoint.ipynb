# %%
from requests import get

# %%
url = "https://www.sephora.com/beauty/new-skin-care-products?icid2=meganav_new_justarrived_skincare_link"

# %%
response = get(url)
response
# Out:
# <Response [200]>

# %%
from bs4 import BeautifulSoup as bs 
html_soup = bs(response.text,'html.parser')
type(html_soup)
print(html_soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="css-1d5zq39" data-comp="Index" lang="en">
#  <head data-comp="Head">
#   <title>
#    New Skin Care Products | Sephora
#   </title>
#   <script src="/js/ufe/isomorphic/thirdparty/sephora_common.js">
#   </script>
#   <meta content="width=1024" name="viewport"/>
#   <meta content="Shop new skin care products at Sephora. Freshen up your routine with one of our newest moisturizers, face oils, night creams or masks." name="description"/>
#   <link href="https://www.sephora.com/new-skin-care-products" rel="canonical"/>
#   <link href="https://m.sephora.com/new-skin-care-products" media="only screen and (max-width: 640px)" rel="alternate"/>
#   <meta content="Shop new skin care products at Sephora. Freshen up your routine with one of our newest moisturizers, face oils, night creams or masks." property="og:description"/>
#   <meta content="New Skin Care Products | Sephora" property="og:title"/>
#   <meta content="website" property="og:type"/>
# ...

# %%
#id_check = html_soup.find(id ="main")
#movie_container = html_soup.find('div', attrs={'class':'css-81z9n1'})
movie_container = html_soup.find_all('div', class_='css-ksbumn')
movie_container
# Out:
# []

# %%
movie_container

# %%
from bs4 import BeautifulSoup
import requests
# Here, we're just importing both Beautiful Soup and the Requests library
page_link = 'the_url_you_want_to_scrape.scrape_it_real_good.com'
# this is the url that we've already determined is safe and legal to scrape from.
page_response = requests.get(page_link, timeout=5)
# here, we fetch the content from the url, using the requests library
page_content = BeautifulSoup(page_response.content, "html.parser")
#we use the html parser to parse the url content and store it in a variable.

# %%
main_content =  html_soup.find_all('div',attrs={"class":"css-1s223mm"})

main_content
# Out:
# []

# %%
makeup_container = id_check.findall("div", class_="css-1s223mm")
len(makeup_container)


#id_check = html_soup.find(id ="main")
#movie_container = id_check.find_all(class_ ="lister-item mode-advanced")
#len(movie_container)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-344-25e70658255f> in <module>
# ----> 1 makeup_container = id_check.findall("div", class_="css-1s223mm")
#       2 len(makeup_container)
#       3
#       4
#       5 #id_check = html_soup.find(id ="main")
#
# AttributeError: 'NoneType' object has no attribute 'findall'

# %%
container
# Out:
# <div class="css-1o80i28 " data-comp="Container Flex Box"><div class="css-1acsadp " data-comp="Flex Box"><div><div class="css-79elbk" data-comp="MarketingMessage"></div></div><div class="css-lodlfe " data-comp="Flex Box"><a class="css-1isu5f3 " data-comp="Reorder Link Box" href="/purchase-history"><svg aria-hidden="true" class="css-znnzps " data-comp="IconReorder Icon Box" viewbox="0 0 24 24"><path d="M15.1 19.1H4.2c-.5 0-.9.4-.9.9s.4.9.9.9h10.9c.5 0 .9-.4.9-.9s-.4-.9-.9-.9zM13.5 22.2H6c-.5 0-.9.4-.9.9s.4.9.9.9h7.5c.5 0 .9-.4.9-.9s-.4-.9-.9-.9zM18.5 12.6h-2.1c0-.1-.1-.2-.2-.3l-5.8-5.8-.1-.1c-.2-.2-.5-.3-.8-.2-.2 0-.3.1-.4.2l-.1.1-5.8 5.8c-.1.1-.2.2-.2.3H.9c-.5 0-.9.4-.9.8 0 .5.4.9.9.9h17.6c.5 0 .9-.4.9-.9 0-.4-.4-.8-.9-.8zm-13.1 0l4.3-4.3 4.3 4.3H5.4zM16.8 16H2.6c-.5 0-.9.4-.9.9s.4.9.9.9h13.9l1-.3c.2-.2.2-.4.2-.6 0-.5-.4-.9-.9-.9zM22 4.9c-2.5-2.8-6.5-3.5-9.7-2l.5-1.9c.1-.4-.2-.9-.6-1-.4-.1-.9.2-1 .6l-.9 3.9s-.2.8.5.9l4 .9h.4c.3-.1.5-.3.6-.6.1-.4-.2-.9-.6-1l-2-.5c2.6-1.2 5.8-.6 7.7 1.6
# ...

# %%
container = makeup_container[0]
meta = container.find("span",class_ = "css-14czj4k").text
print(meta)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-288-48f8724777d9> in <module>
# ----> 1 container = makeup_container[0]
#       2 meta = container.find("span",class_ = "css-14czj4k").text
#       3 print(meta)
#
# IndexError: list index out of range

# %%
cosmet_names = [ ]

# %%
#extract data from individual movie container
for contain in makeup_container:
    
   
    #if movie has Metascore, then extract:
    if contain.find(brand_name= "Drunk Elephant") is not None:
        
        
        #the movie_name
        name = contain.a.text
        cosmet_names.append(name)

# %%
cosmet_names
# Out:
# ['ReorderNEW', 'ReorderNEW']

# %%
for container in makeup_container:
    name = container.find("span",class_ = "css-a2osvj ")
    cosmetic_names.append(name)

#          release = container.find("span", class_ = "lister-item-year text-muted unbold").text
#         year_release.append(release)

# %%
cosmetic_names
# Out:
# [None, None, None, None, None, None]

# %%
import pandas as pd

# %%
test_df = pd.DataFrame({"cosmetic_names":cosmetic_names})
test_df
# Out:
#   cosmetic_names
# 0           None
# 1           None
# 2           None
# 3           None
# 4           None
# 5           None
